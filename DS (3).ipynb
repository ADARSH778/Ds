# %%
import pandas as pd
df=pd.DataFrame({"a":[4,5,6],"b":[7,8,9],"c":[10,11,12]},index=[1,2,3])
print(df)
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
import pandas as pd
data=[1,2,3,4]
df=pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
import pandas as pd
data=[["Alex",10],["Bob",20]]
df=pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#    Name  Age
# 0  Alex   10
# 1   Bob   20

# %%
import pandas as pd
data={'cars':['BMW','VOLVO','FORD'],'passings':[3,7,2]}
df=pd.DataFrame(data)
print(df)
# Out:
#     cars  passings
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2

# %%
import pandas as pd
data=[{"a":1,"b":2},{"a":5,"b":10,"c":20}]
df=pd.DataFrame(data)
df1=pd.DataFrame(data,index=['first','second'],columns=['a','b'])
df1
# Out:
#         a   b
# first   1   2
# second  5  10

# %%
import pandas as pd
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Height':[5.1,6.2,5.1,5.2],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
address=['Chennai','Bangalore','Ooty','Bombay']
df['Address']=address
df
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           MSC    Chennai
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           MSC       Ooty
# 3    Anuj     5.2            BA     Bombay

# %%
import pandas as pd
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Height':[5.1,6.2,5.1,5.2],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
address=['Chennai','Bangalore','Ooty','Bombay']
df['Address']=address
del df['Address']
df
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           MSC
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           MSC
# 3    Anuj     5.2            BA

# %%
import pandas as pd
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Height':[5.1,6.2,5.1,5.2],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
address=['Chennai','Bangalore','Ooty','Bombay']
df['Address']=address
df.drop(['Address'],axis=1,inplace=True)
df
# Out:
#      Name  Height Qualification
# 0     Jai     5.1           MSC
# 1  Princi     6.2            MA
# 2  Gaurav     5.1           MSC
# 3    Anuj     5.2            BA

# %%
import pandas as pd
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Height':[5.1,6.2,5.1,5.2],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
address=['Chennai','Bangalore','Ooty','Bombay']
df['Address']=address
df.drop(['Address'],axis=1,inplace=True)
df.pop('Height')
df
# Out:
#      Name Qualification
# 0     Jai           MSC
# 1  Princi            MA
# 2  Gaurav           MSC
# 3    Anuj            BA

# %%
import pandas as pd
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,56,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df
df.rename(columns={'Address':'place'},inplace=True)
df
# Out:
#      Name  Age      place Qualification
# 0     Jai   27    Chennai           MSC
# 1  Princi   24  Bangalore            MA
# 2  Gaurav   56       Ooty           MSC
# 3    Anuj   45     Bombay            BA

# %%
import pandas as pd
df=pd.DataFrame([[1,2],[3,4]],columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]],columns=['a','b'])
df=pd.concat([df,df2])
df
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,56,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df.drop(2,axis=0,inplace=True)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27    Chennai           MSC
# 1  Princi   24  Bangalore            MA
# 3    Anuj   45     Bombay            BA

# %%
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,56,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df=df['Name']
df
# Out:
# 0       Jai
# 1    Princi
# 2    Gaurav
# 3      Anuj
# Name: Name, dtype: object

# %%
data={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,56,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
print(df[['Name','Qualification']])
# Out:
#      Name Qualification
# 0     Jai           MSC
# 1  Princi            MA
# 2  Gaurav           MSC
# 3    Anuj            BA

# %%
data={'Name':['Jai','Ajey','Gaurav','Anuj'],'Age':[27,24,56,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df.filter(items=['Name','Age'])
df.filter(like='ame')
df.filter(regex='a|e',axis=1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27    Chennai           MSC
# 1    Ajey   24  Bangalore            MA
# 2  Gaurav   56       Ooty           MSC
# 3    Anuj   45     Bombay            BA

# %%
data={'Name':['Jai','Ajey','Gaurav','Anuj'],'Age':[27,24,27,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df=df.drop_duplicates(subset=(['Age']))
df
# Out:
#    Name  Age    Address Qualification
# 0   Jai   27    Chennai           MSC
# 1  Ajey   24  Bangalore            MA
# 3  Anuj   45     Bombay            BA

# %%
data={'Name':['Jai','Ajey','Jai','Anuj'],'Age':[27,24,27,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df=df.drop_duplicates(subset=(['Name','Age']),keep='last')
df
# Out:
#    Name  Age    Address Qualification
# 1  Ajey   24  Bangalore            MA
# 2   Jai   27       Ooty           MSC
# 3  Anuj   45     Bombay            BA

# %%
data={'Name':['Jai','Ajey','Gaurav','Anuj'],'Age':[27,24,27,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
dfs=df.sample(n=2)
dfs
# Out:
#    Name  Age    Address Qualification
# 1  Ajey   24  Bangalore            MA
# 3  Anuj   45     Bombay            BA

# %%
data={'Name':['Jai','Ajey','Gaurav','Anuj'],'Age':[27,24,27,45],'Address':['Chennai','Bangalore','Ooty','Bombay'],'Qualification':['MSC','MA','MSC','BA']}
df=pd.DataFrame(data)
df_sample=df.sample(frac=0.5)
df_sample
# Out:
#    Name  Age    Address Qualification
# 1  Ajey   24  Bangalore            MA
# 3  Anuj   45     Bombay            BA

# %%
import pandas as pd
data={'name':['Alice','Bob','Charlie','David'],'age':[25,30,35,40],'salary':[20000,45000,23000,67000],'gender':['F','M','F','M']}
df=pd.DataFrame(data)
top=df.nlargest(1,columns='salary') #(nsmallest) for smaller salary
print(top)
# Out:
#     name  age  salary gender
# 3  David   40   67000      M

# %%
a=df.query('age>30')
print(a)
# Out:
#       name  age  salary gender
# 2  Charlie   35   23000      F
# 3    David   40   67000      M

# %%
a=df.query('name.str.contains("a") and salary>40000')
print(a)
# Out:
#     name  age  salary gender
# 3  David   40   67000      M

# %%
a=df.query(' gender == ["F","M"] and age>30')
a
# Out:
#       name  age  salary gender
# 2  Charlie   35   23000      F
# 3    David   40   67000      M

# %%
a=df.loc[:,'age']
a
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: age, dtype: int64

# %%
b=df.iloc[:,0]
b
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: name, dtype: object

# %%
a=df.loc[:,['name','age']]
a
# Out:
#       name  age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
a=df[df['age']>30]
a
# Out:
#       name  age  salary gender
# 2  Charlie   35   23000      F
# 3    David   40   67000      M

# %%
a=df[(df['gender']== 'F') & (df['age']>30)]
a
# Out:
#       name  age  salary gender
# 2  Charlie   35   23000      F

# %%
a=df[df['name'].str.startswith(('A','C'))]
a
# Out:
#       name  age  salary gender
# 0    Alice   25   20000      F
# 2  Charlie   35   23000      F

# %%
print(df.tail(2)) #head for first to last
# Out:
#       name  age  salary gender
# 2  Charlie   35   23000      F
# 3    David   40   67000      M

# %%
print(df.head(2))
# Out:
#     name  age  salary gender
# 0  Alice   25   20000      F
# 1    Bob   30   45000      M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   salary  4 non-null      int64
#  3   gender  4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe()
# Out:
#              age        salary
# count   4.000000      4.000000
# mean   32.500000  38750.000000
# std     6.454972  21884.164747
# min    25.000000  20000.000000
# 25%    28.750000  22250.000000
# 50%    32.500000  34000.000000
# 75%    36.250000  50500.000000
# max    40.000000  67000.000000

# %%
import pandas as pd
data={'name':['Alice','Bon','Charlie','David','Emily'],'gender':['M','M','F','M','F'],'age':[25,30,56,74,36],'salary':[50000,34000,78000,32000,60000]}
df=pd.DataFrame(data)
a=df.groupby('gender').mean()['salary']
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1873         try:
# -> 1874             res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     848
# --> 849         result = self._aggregate_series_pure_python(obj, func)
#     850
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     876         for i, group in enumerate(splitter):
# --> 877             res = func(group)
#     878             res = extract_result(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2379                 "mean",
# -> 2380                 alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6224     ):
# -> 6225         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6226
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11948
# > 11949         return self._reduce(
#   11950             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6132                 )
# -> 6133             return op(delegate, skipna=skipna, **kwds)
#    6134
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1692             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694         try:
#
# TypeError: Could not convert string 'CharlieEmily' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-1d3c4a8c3def> in <cell line: 4>()
#       2 data={'name':['Alice','Bon','Charlie','David','Emily'],'gender':['M','M','F','M','F'],'age':[25,30,56,74,36],'salary':[50000,34000,78000,32000,60000]}
#       3 df=pd.DataFrame(data)
# ----> 4 a=df.groupby('gender').mean()['salary']
#       5 a
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2376             )
#    2377         else:
# -> 2378             result = self._cython_agg_general(
#    2379                 "mean",
#    2380                 alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1927             return result
#    1928
# -> 1929         new_mgr = data.grouped_reduce(array_func)
#    1930         res = self._wrap_agged_manager(new_mgr)
#    1931         out = self._wrap_aggregated_output(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1426                 #  while others do not.
#    1427                 for sb in blk._split():
# -> 1428                     applied = sb.apply(func)
#    1429                     result_blocks = extend_blocks(applied, result_blocks)
#    1430             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     364         one
#     365         """
# --> 366         result = func(self.values, **kwargs)
#     367
#     368         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1924                 return result
#    1925
# -> 1926             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927             return result
#    1928
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1876             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877             # preserve the kind of exception that raised
# -> 1878             raise type(err)(msg) from err
#    1879
#    1880         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]
